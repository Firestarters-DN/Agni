# %%
import osmnx as ox
import sklearn
from IPython.display import Image

# %%
# %matplotlib inline
img_folder = 'images'
extension = 'png'
size = 240
graph = ox.graph_from_place("Napa Valley, California", simplify= True, network_type = "drive")
fig, ax = ox.plot_graph(ox.project_graph(graph))
# Out:
# /home/mishkasistrunk/anaconda3/envs/ox/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
retail_tags = {'landuse':['retail']}
napa_retail = ox.geometries_from_place("Napa Valley, California", retail_tags)
napa_retail_proj = ox.project_gdf(napa_retail)
file_path = f'./home/mishkasistrunk/codeWork/fireStart/imageFiles/napa_retail.{extension}'
fig, ax = ox.plot_footprints(napa_retail_proj, filepath=file_path, dpi=400, save=True, show=False, close=True)
Image(file_path, height=size, width=size)
# Out:
# /home/mishkasistrunk/anaconda3/envs/ox/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
